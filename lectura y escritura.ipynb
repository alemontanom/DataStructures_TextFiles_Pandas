# %% [markdown]
# ### Lectura de archivos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Vamos a abrir un archivo en modo de lectura primero usemos CURP.txt

# %%
id=open("CURPA.txt","r")
resultado=id.read()
id.close()

# %% [markdown]
# ### Observa los datos que se crearon

# %%
resultado #imprime la cadena de textos
# Out:
# 'TEPQ150322HPLKTD09,GUFS151123HQRDMKQ1,KUYU740709HYNXDY2O,FIQR680403HCHQNF85,ZIBY700712MSRCTT7Q,CAMC470413MCSTWY96,QECG660827MOCDHYA1,LAGK021129HDFNVYH5,IIWQ110328MYNXFGM5,VAHB490117HSLNFXX2,BUMZ411006HSLVXW5M,ZOLX721007MJCXHKH0,LEJJ590306HCLVPQ77,TONR630827HTCKLMS5,HEPK440421HGTNQR40,PAWW010401HGRKGB74,JIAJ421017HTCPPXG7,VOPY740723HGTCXDE0,MUSF140628MCLXSZU3,UIQH521126HNTMRV91,TIHV641208MMNCGJR2,AACW510520MGTJFVO2,FELK690125MZSQHFU3,LUDL490621MSRSWGT2,XAEN110415HJCVWTA6,CUOE060329MNLPQTA3,YEJJ540405HMCBPV15,TUBB740603HDFBGM7I,DEOH480704MCMJNY3H,JUYS871003HQTZMLF3,UUUP141230MYNQXXM6,BEPS020324HTLSXY3S,PALZ900805HMSMMG41,FUHH960717MOCKWF73,KUSQ051129MZSJLXWH,PUUW770211MASZBLP4,QIIZ090317HCHYNDFH,POMB850604MTSRHX09,MEDG510906HPLHSRL6,WIUK470302HJCCJX3B,OOZV480413MTLMKH2G,LAZY130409HTCZLC70,EIGG750312HASDYYJ7,HERR090623MZSFWYQ2,IEUC740308HHGCWSA5,NUKL501115HOCBMW46,LATV951203MJCKCP10,QEPE500301HTSFSWW9,DEPR560213MGRVVF1U,PEVS040814HYNPDBC2,AEAT780419HPLDJWU6,LAQF961012MOCMNTB4,HEWW98072
# ...

# %% [markdown]
# ### Manipularlos para poder trabajar

# %%
separados=resultado.split(",") #El split genera una estructura nueva pero no sobreescribe, entonces no se guarda
# Out:
#   File "<ipython-input-11-e4fa76b6a469>", line 1
#     separados=resultado.split(,) #El split genera una estructura nueva pero no sobreescribe, entonces no se guarda
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Repite el procedimiento con CURPA.txt  y CURPB.txt

# %%
id=open("CURPB.txt","r")
resultadoB=id.read()
id.close()

# %%
resultadoB
# Out:
# 'BOFQ061001HSPGMH51#XOGI961207HOCVKR67#AEQM070315HBSZMKL3#MUBI650817HCSSJN80#EEPL591212MQTQDQW9#OOMV550716HTLSBM11#BAUP421224MJCGFDPC#ZIDJ550903MCHNBD44#MUGN931112HCCDZHX0#NONI630710HHGRGT24#DOCH930111HTSZCDK6#LOCT810802HCMYJB0E#BIIW140410MMSXJRB6#VIYU900226HYNFHRE9#BAJG480215MSRQJN75#DOBJ490627MQTJNK77#TEDD890822HCSGTTI8#BUJW960520HZSNHC53#QEMM521221HMSJFJVK#KANJ030808MCLXKKY0#XAUL950404HCMMNX03#DUJB080912MCSVNN03#NEMM451204HASVMDT7#UAYP451019HGRBQGF8#HOFU610704MVZXVZTI#BENE770107MYNYWMZI#POXA461211MCMGDF48#AAAO921001HTSPSK59#EEOY711103HCMDHB8R#KIGW801214HCMDNC83#IEPZ650605MHGNMHG4#GUWU010406MTLXNL98#JIWS960824MMNPVBE1#WOTQ540715MZSQWCI9#OUOU000706MVZSZLL3#YUER941004HQRVQC34#JEDO400717HMCWQW47#OOEB540812HCMWHSP2#HAGU820830MMNJBY93#AOOK950201HCMMHZ57#ZATZ710501HASZDRG6#ZIYK690914HCLRBTZ2#NUKP030801MGRFVM14#UIVU150522HZSCPFQ4#MIQW871221HGTWCW32#SOEF981014HCHKLQ00#NEYO990723HOCKQKB7#JABW450211MMSWHF73#SUKY860304MQTNKZM5#JAVP830506MSPLQL39#BAKX450404HVZTSQ52#BUEK130310HVZXJZ17#VERW54070
# ...

# %%
Bsep=resultadoB.split("#")

# %%
Bsep
# Out:
# ['BOFQ061001HSPGMH51',
#  'XOGI961207HOCVKR67',
#  'AEQM070315HBSZMKL3',
#  'MUBI650817HCSSJN80',
#  'EEPL591212MQTQDQW9',
#  'OOMV550716HTLSBM11',
#  'BAUP421224MJCGFDPC',
#  'ZIDJ550903MCHNBD44',
#  'MUGN931112HCCDZHX0',
#  'NONI630710HHGRGT24',
#  'DOCH930111HTSZCDK6',
#  'LOCT810802HCMYJB0E',
#  'BIIW140410MMSXJRB6',
#  'VIYU900226HYNFHRE9',
#  'BAJG480215MSRQJN75',
#  'DOBJ490627MQTJNK77',
#  'TEDD890822HCSGTTI8',
#  'BUJW960520HZSNHC53',
#  'QEMM521221HMSJFJVK',
#  'KANJ030808MCLXKKY0',
#  'XAUL950404HCMMNX03',
#  'DUJB080912MCSVNN03',
#  'NEMM451204HASVMDT7',
#  'UAYP451019HGRBQGF8',
#  'HOFU610704MVZXVZTI',
#  'BENE770107MYNYWMZI',
#  'POXA461211MCMGDF48',
#  'AAAO921001HTSPSK59',
#  'EEOY711103HCMDHB8R',
#  'KIGW801214HCMDNC83',
#  'IEPZ650605MHGNMHG4',
#  'GUWU010406MTLXNL98',
#  'JIWS960824MMNPVBE1',
#  'WOTQ540715MZSQWCI9',
#  'OUOU000706MVZSZLL3',
#  'YUER941004HQRVQC34',
#  'JEDO400717HMCWQW47',
#  'OOEB540812HCMWHSP2',
#  'HAGU820830MMNJBY93',
#  'AOOK950201HCMMHZ57',
# ...

# %%
len(Bsep)
# Out:
# 86

# %% [markdown]
# ### Creacion de archivo

# %%
id=open("prueba2.txt","w")
id.close()

# %% [markdown]
# ### Escritura de archivo

# %%
id=open("prueba2.txt","a") #si lo dejas con w te va a borrar lo que ya tenías, con a se van agregando cosas al final
n=input("¿Como te llamas? ")
e=input("Cuál es tu edad ")
id.write("\n"+n+","+e)
id.close()
# Out:
# ¿Como te llamas? Roberto
# Cuál es tu edad 20

# %%
id=open("prueba2.txt","r")
pruebaleer=id.read()
id.close()

# %%
pruebaleer
# Out:
# '\nAle, 19\nRoberto\n20'

# %%
id=open("pruebac2.txt","w")
id.write("5,5,9")
id.close()

# %% [markdown]
# ### Ejercicio 1
#
# Desarrolla una funcion que dado la curp de una persona regrese el codigo de su entidad de nacimiento

# %%
separados
# Out:
# ['TEPQ150322HPLKTD09',
#  'GUFS151123HQRDMKQ1',
#  'KUYU740709HYNXDY2O',
#  'FIQR680403HCHQNF85',
#  'ZIBY700712MSRCTT7Q',
#  'CAMC470413MCSTWY96',
#  'QECG660827MOCDHYA1',
#  'LAGK021129HDFNVYH5',
#  'IIWQ110328MYNXFGM5',
#  'VAHB490117HSLNFXX2',
#  'BUMZ411006HSLVXW5M',
#  'ZOLX721007MJCXHKH0',
#  'LEJJ590306HCLVPQ77',
#  'TONR630827HTCKLMS5',
#  'HEPK440421HGTNQR40',
#  'PAWW010401HGRKGB74',
#  'JIAJ421017HTCPPXG7',
#  'VOPY740723HGTCXDE0',
#  'MUSF140628MCLXSZU3',
#  'UIQH521126HNTMRV91',
#  'TIHV641208MMNCGJR2',
#  'AACW510520MGTJFVO2',
#  'FELK690125MZSQHFU3',
#  'LUDL490621MSRSWGT2',
#  'XAEN110415HJCVWTA6',
#  'CUOE060329MNLPQTA3',
#  'YEJJ540405HMCBPV15',
#  'TUBB740603HDFBGM7I',
#  'DEOH480704MCMJNY3H',
#  'JUYS871003HQTZMLF3',
#  'UUUP141230MYNQXXM6',
#  'BEPS020324HTLSXY3S',
#  'PALZ900805HMSMMG41',
#  'FUHH960717MOCKWF73',
#  'KUSQ051129MZSJLXWH',
#  'PUUW770211MASZBLP4',
#  'QIIZ090317HCHYNDFH',
#  'POMB850604MTSRHX09',
#  'MEDG510906HPLHSRL6',
#  'WIUK470302HJCCJX3B',
# ...

# %%
m=0
h=0
for i in range(0, len(separados)):
    if separados[i][10]=="M":
        m=m+1
    else : 
        h=h+1
pie([m,h], labels=["Mujeres", "Hombres"],autopct="%1.1f%%")
#se puede hacer en menos lineas con list comprehension
# Out:
# ([<matplotlib.patches.Wedge at 0x7fddde6bf7c0>,
# ...
#  [Text(0.29221180684583664, 1.060477373610532, 'Mujeres'),
#   Text(-0.29221180684583675, -1.060477373610532, 'Hombres')],
#  [Text(0.15938825827954722, 0.5784422037875628, '41.4%'),
#   Text(-0.1593882582795473, -0.5784422037875628, '58.6%')])

# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['e']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# Aplica la funcion en el curp  TEPQ150322HPLKTD09
